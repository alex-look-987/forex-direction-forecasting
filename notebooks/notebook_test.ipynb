# %% [markdown]
# # Testing jupyter notebooks into project env

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
array = np.array([])
aa = array.copy()
